# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
#rcParams['figure.figsize'] = 25, 8
import sys
from pandas.core import datetools
from datetime import datetime
from matplotlib.ticker import NullFormatter

# %%
data = pd.read_csv('/home/vivek/Documents/Data_Science/Data_Sets/Electricity/HomeA/2016/HomeA-meter4_2016.csv')
print data.head()
# Out:
#            Date & Time  use [kW]  gen [kW]  KitchenDenLights [kW]  \
# 0  2016-01-01 00:00:00       0.0       0.0               0.007658
# 1  2016-01-01 00:15:00       0.0       0.0               0.007607
# 2  2016-01-01 00:30:00       0.0       0.0               0.007591
# 3  2016-01-01 00:45:00       0.0       0.0               0.007613
# 4  2016-01-01 01:00:00       0.0       0.0               0.007593
#
#    MasterBedBathLights [kW]  MasterOutlets [kW]  DenOutdoorLights [kW]  \
# 0                  0.021299            0.021406               0.000456
# 1                  0.004709            0.021479               0.000487
# 2                  0.004656            0.020737               0.000480
# 3                  0.004643            0.020870               0.000496
# 4                  0.004641            0.020090               0.000494
#
#    DenOutlets [kW]  RearBasementLights [kW]  KitchenOutletsEast [kW]  \
# ...

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m-%d %H:%M:%S')
data = pd.read_csv('/home/vivek/Documents/Data_Science/Data_Sets/Electricity/HomeA/2016/HomeA-meter2_2016.csv', parse_dates=['Date & Time'], index_col='Date & Time',date_parser=dateparse, nrows=1488)
print data.head()
# Out:
#                      use [kW]  gen [kW]  FurnaceHRV [kW]  CellarOutlets [kW]  \
# Date & Time
# 2016-01-01 00:00:00       0.0       0.0         0.084142            0.113495
# 2016-01-01 00:30:00       0.0       0.0         0.009887            0.028861
# 2016-01-01 01:00:00       0.0       0.0         0.044926            0.086999
# 2016-01-01 01:30:00       0.0       0.0         0.037721            0.049664
# 2016-01-01 02:00:00       0.0       0.0         0.010029            0.065564
#
#                      WashingMachine [kW]  FridgeRange [kW]  \
# Date & Time
# 2016-01-01 00:00:00             0.000123          0.001031
# 2016-01-01 00:30:00             0.000007          0.001053
# 2016-01-01 01:00:00             0.000083          0.001052
# 2016-01-01 01:30:00             0.000064          0.001056
# 2016-01-01 02:00:00             0.000011          0.001069
#
#                      DisposalDishwasher [kW]  KitchenLights [kW]  \
# Date & Time
# ...

# %%
data=data.resample('1D').sum()
p = plt.figure(figsize=(18, 12))
data.plot(kind='bar', ax=p.gca())
date = pd.date_range('2016-01-01', '2016-01-31')
plt.xticks(np.arange(len(date)), [datetime.strftime(i, '%m/%d') for i in date], rotation=45)
plt.title('Energy Consumptions per day')
plt.xlabel('date')
plt.ylabel('energy consumption(kW)')

# %%
plt.subplots(figsize=(16,10))
data1=data['FurnaceHRV [kW]']
plt.subplot(321)
data1.plot(kind='bar')
date = pd.date_range('2016-01-01', '2016-01-31')
plt.xticks(np.arange(len(date)), [datetime.strftime(i, '%m/%d') for i in date], rotation=45)
plt.title('Energy Consumptions of FurnaceHRV per day')
plt.xlabel('date')
plt.ylabel('energy consumption(kW)')

data2=data['CellarOutlets [kW]']
plt.subplot(322)
data2.plot(kind='bar')
date = pd.date_range('2016-01-01', '2016-01-31')
plt.xticks(np.arange(len(date)), [datetime.strftime(i, '%m/%d') for i in date], rotation=45)
plt.title('Energy Consumptions of CellarOutlets per day')
plt.xlabel('date')
plt.ylabel('energy consumption(kW)')

data3=data['WashingMachine [kW]']
plt.subplot(323)
data3.plot(kind='bar')
date = pd.date_range('2016-01-01', '2016-01-31')
plt.xticks(np.arange(len(date)), [datetime.strftime(i, '%m/%d') for i in date], rotation=45)
plt.title('Energy Consumptions of WashingMachine per day')
plt.xlabel('date')
plt.ylabel('energy consumption(kW)')

data4=data['FridgeRange [kW]']
plt.subplot(324)
data4.plot(kind='bar')
date = pd.date_range('2016-01-01', '2016-01-31')
plt.xticks(np.arange(len(date)), [datetime.strftime(i, '%m/%d') for i in date], rotation=45)
plt.title('Energy Consumptions of FridgeRange  per day')
plt.xlabel('date')
plt.ylabel('energy consumption(kW)')

data5=data['DisposalDishwasher [kW]']
plt.subplot(325)
data5.plot(kind='bar')
date = pd.date_range('2016-01-01', '2016-01-31')
plt.xticks(np.arange(len(date)), [datetime.strftime(i, '%m/%d') for i in date], rotation=45)
plt.title('Energy Consumptions of DisposalDishwasher  per day')
plt.xlabel('date')
plt.ylabel('energy consumption(kW)')

data6=data['KitchenLights [kW]']
plt.subplot(326)
data6.plot(kind='bar')
date = pd.date_range('2016-01-01', '2016-01-31')
plt.xticks(np.arange(len(date)), [datetime.strftime(i, '%m/%d') for i in date], rotation=45)
plt.title('Energy Consumptions of KitchenLights  per day')
plt.xlabel('date')
plt.ylabel('energy consumption(kW)')

plt.gca().yaxis.set_minor_formatter(NullFormatter())
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=1,
                    wspace=0.35)
plt.show()
